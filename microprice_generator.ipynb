# %%
import os
import glob
import dask

import numpy as np
import pandas as pd

from typing import List
from datetime import datetime
from src.preprocessing import extract_features, symmetrize_data
from src.microprice import get_micro_adjustment

# %%
def get_file_date(path: str) -> str:
    file_name = os.path.split(path)[1]
    next_date = file_name.split("_")[-2]
    return next_date

# %%
# set the path for raw and preprocessed folder 
# set the asset pair that you would like to calculate the microprice
ASSET = 'ethusdt'
RAW_DATA_PATH = '/Users/mac/Desktop/Repos/FBD_Project/datasets/raw/'
PRC_DATA_PATH = '/Users/mac/Desktop/Repos/FBD_Project/datasets/processed/'

orderbook_list = sorted(glob.glob(RAW_DATA_PATH + ASSET + '/orderbook/*.csv.gz'))
# quote_list = sorted(glob.glob(RAW_DATA_PATH + ASSET + '/quotes/*.csv.gz'))
# trade_list = sorted(glob.glob(RAW_DATA_PATH + ASSET + 'btcusdt/trades/*.csv.gz'))

# %%
win_len = 5

# for each window of specified length,
# process raw data to get features for calculation.
print(f'Start microprice calculation. (Asset {ASSET})')
for i in range(win_len, len(orderbook_list)):
    next_date = get_file_date(orderbook_list[i])
    print(f'Processing... (date: {next_date}, progress: {i-5}/{len(orderbook_list) - 1 - 5})')
    
    # extract raw data
    all_features = [extract_features(path) for path in orderbook_list[i-win_len:i]] 
    df_feat = dask.compute(all_features)[0]
    df_feat = pd.concat(df_feat)

    # symmetrized data (for obtaining microprice)
    df_sym = symmetrize_data(df_feat, symmetrize=True)

    # get micro adjustment and save micro adjustment matrix.
    df_micro = get_micro_adjustment(df_sym)
    df_micro.to_csv(PRC_DATA_PATH + f'microprice/{ASSET}/micro_adjustment_{next_date}.csv')
# Out:
# Start microprice calculation. (Asset ethusdt)
# Processing... (date: 2022-09-07, progress: 0/114)
# Processing... (date: 2022-09-08, progress: 1/114)
# Processing... (date: 2022-09-09, progress: 2/114)
# Processing... (date: 2022-09-10, progress: 3/114)
# Processing... (date: 2022-09-11, progress: 4/114)
# Processing... (date: 2022-09-12, progress: 5/114)
# Processing... (date: 2022-09-13, progress: 6/114)
# Processing... (date: 2022-09-14, progress: 7/114)
# Processing... (date: 2022-09-15, progress: 8/114)
# Processing... (date: 2022-09-16, progress: 9/114)
# Processing... (date: 2022-09-17, progress: 10/114)
# Processing... (date: 2022-09-18, progress: 11/114)
# Processing... (date: 2022-09-19, progress: 12/114)
# Processing... (date: 2022-09-20, progress: 13/114)
# Processing... (date: 2022-09-21, progress: 14/114)
# Processing... (date: 2022-09-22, progress: 15/114)
# Processing... (date: 2022-09-23, progress: 16/114)
# Processing... (date: 2022-09-24, progress: 17/114)
# Processing... (date: 2022-09-25, progress: 18/114)
# Processing... (date: 2022-09-26, progress: 19/114)
# Processing... (date: 2022-09-27, progress: 20/114)
# Processing... (date: 2022-09-28, progress: 21/114)
# Processing... (date: 2022-09-29, progress: 22/114)
# Processing... (date: 2022-09-30, progress: 23/114)
# Processing... (date: 2022-10-01, progress: 24/114)
# Processing... (date: 2022-10-02, progress: 25/114)
# Processing... (date: 2022-10-03, progress: 26/114)
# Processing... (date: 2022-10-04, progress: 27/114)
# Processing... (date: 2022-10-05, progress: 28/114)
# Processing... (date: 2022-10-06, progress: 29/114)
# Processing... (date: 2022-10-07, progress: 30/114)
# Processing... (date: 2022-10-08, progress: 31/114)
# Processing... (date: 2022-10-09, progress: 32/114)
# Processing... (date: 2022-10-10, progress: 33/114)
# Processing... (date: 2022-10-11, progress: 34/114)
# Processing... (date: 2022-10-12, progress: 35/114)
# Processing... (date: 2022-10-13, progress: 36/114)
# Processing... (date: 2022-10-14, progress: 37/114)
# Processing... (date: 2022-10-15, progress: 38/114)
# Processing... (date: 2022-10-16, progress: 39/114)
# Processing... (date: 2022-10-17, progress: 40/114)
# Processing... (date: 2022-10-18, progress: 41/114)
# Processing... (date: 2022-10-19, progress: 42/114)
# Processing... (date: 2022-10-20, progress: 43/114)
# Processing... (date: 2022-10-21, progress: 44/114)
# Processing... (date: 2022-10-22, progress: 45/114)
# Processing... (date: 2022-10-23, progress: 46/114)
# Processing... (date: 2022-10-24, progress: 47/114)
# Processing... (date: 2022-10-25, progress: 48/114)
# Processing... (date: 2022-10-26, progress: 49/114)
# Processing... (date: 2022-10-27, progress: 50/114)
# Processing... (date: 2022-10-28, progress: 51/114)
# Processing... (date: 2022-10-29, progress: 52/114)
# Processing... (date: 2022-10-30, progress: 53/114)
# Processing... (date: 2022-10-31, progress: 54/114)
# Processing... (date: 2022-11-01, progress: 55/114)
# Processing... (date: 2022-11-02, progress: 56/114)
# Processing... (date: 2022-11-03, progress: 57/114)
# Processing... (date: 2022-11-04, progress: 58/114)
# Processing... (date: 2022-11-05, progress: 59/114)
# Processing... (date: 2022-11-06, progress: 60/114)
# Processing... (date: 2022-11-07, progress: 61/114)
# Processing... (date: 2022-11-08, progress: 62/114)
# Processing... (date: 2022-11-09, progress: 63/114)
# Processing... (date: 2022-11-10, progress: 64/114)
# Processing... (date: 2022-11-11, progress: 65/114)
# Processing... (date: 2022-11-12, progress: 66/114)
# Processing... (date: 2022-11-13, progress: 67/114)
# Processing... (date: 2022-11-14, progress: 68/114)
# Processing... (date: 2022-11-15, progress: 69/114)
# Processing... (date: 2022-11-16, progress: 70/114)
# Processing... (date: 2022-11-17, progress: 71/114)
# Processing... (date: 2022-11-18, progress: 72/114)
# Processing... (date: 2022-11-19, progress: 73/114)
# Processing... (date: 2022-11-20, progress: 74/114)
# Processing... (date: 2022-11-21, progress: 75/114)
# Processing... (date: 2022-11-22, progress: 76/114)
# Processing... (date: 2022-11-23, progress: 77/114)
# Processing... (date: 2022-11-24, progress: 78/114)
# Processing... (date: 2022-11-25, progress: 79/114)
# Processing... (date: 2022-11-26, progress: 80/114)
# Processing... (date: 2022-11-27, progress: 81/114)
# Processing... (date: 2022-11-28, progress: 82/114)
# Processing... (date: 2022-11-29, progress: 83/114)
# Processing... (date: 2022-11-30, progress: 84/114)
# Processing... (date: 2022-12-01, progress: 85/114)
# Processing... (date: 2022-12-02, progress: 86/114)
# Processing... (date: 2022-12-03, progress: 87/114)
# Processing... (date: 2022-12-04, progress: 88/114)
# Processing... (date: 2022-12-05, progress: 89/114)
# Processing... (date: 2022-12-06, progress: 90/114)
# Processing... (date: 2022-12-07, progress: 91/114)
# Processing... (date: 2022-12-08, progress: 92/114)
# Processing... (date: 2022-12-09, progress: 93/114)
# Processing... (date: 2022-12-10, progress: 94/114)
# Processing... (date: 2022-12-11, progress: 95/114)
# Processing... (date: 2022-12-12, progress: 96/114)
# Processing... (date: 2022-12-13, progress: 97/114)
# Processing... (date: 2022-12-14, progress: 98/114)
# Processing... (date: 2022-12-15, progress: 99/114)
# Processing... (date: 2022-12-16, progress: 100/114)
# Processing... (date: 2022-12-17, progress: 101/114)
# Processing... (date: 2022-12-18, progress: 102/114)
# Processing... (date: 2022-12-19, progress: 103/114)
# Processing... (date: 2022-12-20, progress: 104/114)
# Processing... (date: 2022-12-21, progress: 105/114)
# Processing... (date: 2022-12-22, progress: 106/114)
# Processing... (date: 2022-12-23, progress: 107/114)
# Processing... (date: 2022-12-24, progress: 108/114)
# Processing... (date: 2022-12-25, progress: 109/114)
# Processing... (date: 2022-12-26, progress: 110/114)
# Processing... (date: 2022-12-27, progress: 111/114)
# Processing... (date: 2022-12-28, progress: 112/114)
# Processing... (date: 2022-12-29, progress: 113/114)
# Processing... (date: 2022-12-30, progress: 114/114)

# %%
# symmetrized data (for obtaining microprice)
df_sym = symmetrize_data(df_feat, symmetrize=True)

# df sig will be used for trading signals
df_sig = symmetrize_data(df_feat, symmetrize=False)

# %%
# join micro price table to the df_sig.
df_sig = pd.merge(
            df_sig[['mid_price','ba_spread','imbalance']].reset_index(),
            df_micro.reset_index(),
            how='left',
            left_on=['ba_spread','imbalance'], 
            right_on=['ba_spread','imbalance']
        ).set_index('timestamp')

# micro price calculation: mid_price + g_star
df_sig['micro_price'] = df_sig['mid_price'] + df_sig['g_star']

# %%
# micro price 
df_sig[['mid_price', 'micro_price']]
# Out:
#                      mid_price   micro_price
# timestamp
# 2022-09-02 00:00:00   20122.55  20122.533317
# 2022-09-02 00:00:01   20122.55  20122.533317
# 2022-09-02 00:00:03   20120.75  20120.733317
# 2022-09-02 00:00:08   20124.85  20124.866683
# 2022-09-02 00:00:09   20124.85  20124.854311
# ...                        ...           ...
# 2022-09-06 23:59:48   18779.95  18779.933317
# 2022-09-06 23:59:49   18779.95  18779.933317
# 2022-09-06 23:59:51   18780.55  18780.566683
# 2022-09-06 23:59:54   18784.35  18784.354311
# 2022-09-06 23:59:55   18784.35  18784.354311
#
# [318701 rows x 2 columns]
